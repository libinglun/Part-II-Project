# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot(my_data, zhou_data, num, y_label):
    x = np.linspace(0, 200, num)
    plt.figure(figsize=(10, 5))
    plt.plot(x, my_data, 'o-')
    plt.plot(x, zhou_data, 'o-')
    
    plt.title('Comparison between my iHMM and the benchmark iHMM')
    plt.xlabel('Iterations')
    plt.ylabel(y_label)
    
    plt.legend(['my iHMM', 'benchmark iHMM'])
    
    plt.show()

# %%
x_axis = np.linspace(0, 200, 11)
print([int(n) for n in x_axis])
# Out:
# [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200]

# %%
my_loss = [99.3, 54.7, 41.4, 33.6, 29.3, 26.9, 24.5, 24.0, 24.7, 25.2, 24.6, 23.2, 23.5, 22.5, 20.1, 21.4, 23.5, 22.3, 23.4, 22.6, 24.5]
zhou_loss = [99.2, 40.9, 32.5, 33.2, 29.7, 28.8, 28.0, 29.4, 29.8, 25.9, 24.6, 26.0, 22.7, 20.9, 22.3, 22.3, 22.1, 23.6, 23.0, 23.0, 23.3]
x_axis = np.linspace(0, 200, 21)
# plot(my_loss, zhou_loss, 21, 'Zero One Loss Rate')

# %%
my_k =  [1, 20, 9, 6, 8, 8, 7, 7, 7, 8, 9, 7, 8, 7, 7, 7, 7, 8, 7, 9, 8]
zhou_k = [1, 27, 14, 12, 11, 9, 7, 7, 7, 7, 7, 7, 7, 9, 7, 7, 7, 7, 7, 8, 8]
plot(my_k, zhou_k, 21, 'number of hidden states')

# %%
my_loglik = [-2007.132, -1849.9637702681812, -1776.8436600408054, -1787.6594679606098, -1796.1414489955425, -1766.424561889299, -1773.8738321248672, -1769.2907180368886, -1786.8909135509339, -1813.658457718118, -1777.9367648997325, -1786.8807579970703, -1787.7493873884912, -1784.363103401882, -1772.0055066257628, -1786.7127461316845, -1762.117268246162, -1746.5925835334256, -1753.8135765294176, -1756.8631786137544] 
zhou_loglik = [-2084.826613451231, -1854.5651678770791, -1774.1384143714045, -1772.3507507580468, -1777.8176390895583, -1773.3144625282366, -1781.4370622777578, -1775.064293412104, -1765.834951749017, -1765.067320810349, -1784.1681875732932, -1773.3341771114865, -1766.145350203812, -1746.7808363166957, -1759.6921390278949, -1759.0332957678438, -1815.8947543241732, -1790.0011039438423, -1771.2723431263098, -1781.1284789897304]
plot(my_loglik, zhou_loglik, 20, 'log likelihood of the model')
# Out:
# (0, -2084.8)
# (10, -1854.6)
# (20, -1774.1)
# (30, -1772.4)
# (40, -1777.8)
# (50, -1773.3)
# (60, -1781.4)
# (70, -1775.1)
# (80, -1765.8)
# (90, -1765.1)
# (100, -1784.2)
# (110, -1773.3)
# (120, -1766.1)
# (130, -1746.8)
# (140, -1759.7)
# (150, -1759.0)
# (160, -1815.9)
# (170, -1790.0)
# (180, -1771.3)
# (190, -1781.1)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10, 15))  # 3 rows, 1 column
x = np.linspace(0, 200, 21)
axs[0].plot(x, my_loss, 'o-')
axs[0].plot(x, zhou_loss, 'o-')
axs[0].set_title('Comparison between my iHMM and the benchmark iHMM')
axs[0].set_xlabel('Iterations')
axs[0].set_ylabel('Zero-one loss rate')
axs[0].legend(['my iHMM', 'benchmark iHMM'])

x = np.linspace(0, 200, 21)
axs[1].plot(x, my_k, 'o-')
axs[1].plot(x, zhou_k, 'o-')
# axs[1].title('Comparison between my iHMM and the benchmark iHMM')
axs[1].set_xlabel('Iterations')
axs[1].set_ylabel('Number of hidden states')
axs[1].legend(['my iHMM', 'benchmark iHMM'])

x = np.linspace(0, 200, 20)
axs[2].plot(x, my_loglik, 'o-')
axs[2].plot(x, zhou_loglik, 'o-')
# axs[2].title('Comparison between my iHMM and the benchmark iHMM')
axs[2].set_xlabel('Iterations')
axs[2].set_ylabel('Log-likelihood of the model')
axs[2].legend(['my iHMM', 'benchmark iHMM'])

# %%
import numpy as np
import matplotlib.pyplot as plt

points = [24.5, 24.2, 25.1, 23.9, 21.5, 26.0, 30.0, 18.6, 16.9, 19.7, 30.7, 22.4, 23.9, 21.9, 23.8, 24.3, 24.3, 20.0, 20.8, 22.6]
print(len(points))

np.random.shuffle(points)
midpoint = len(points) // 2
print(midpoint)
y1, y2 = points[:midpoint], points[midpoint:]

x = [i for i in range(1, 11)]

for i in range(10):
    print(tuple((int(x[i]), round(y1[i], 1))))
for i in range(10):
    print(tuple((int(x[i]), round(y2[i], 1))))

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y1, color='red', label='List 1')
plt.scatter(x, y2, color='blue', label='List 2')
plt.title('Scatter Plot of Two iHMMs')
plt.xlabel("nth experiment")
plt.ylabel('Zero-one loss rate')
plt.legend(['my iHMM', 'benchmark iHMM'])
plt.ylim(0, 100)
plt.xticks(x)
plt.grid(True)
plt.show()
# Out:
# 20
# 10
# (1, 24.3)
# (2, 21.9)
# (3, 18.6)
# (4, 26.0)
# (5, 23.8)
# (6, 23.9)
# (7, 30.0)
# (8, 22.4)
# (9, 24.5)
# (10, 20.0)
# (1, 19.7)
# (2, 24.3)
# (3, 20.8)
# (4, 30.7)
# (5, 24.2)
# (6, 25.1)
# (7, 21.5)
# (8, 16.9)
# (9, 22.6)
# (10, 23.9)

# %%
def estimator(results):
    return np.mean(results), np.std(results, ddof=1)

# %%
y1 = 100 - np.array(y1)
y2 = 100 - np.array(y2)
estimator(y1), estimator(y2)
# Out:
# ((76.46000000000001, 3.16936726948596), (77.03, 3.6965599623914596))

# %%
def plot(data1, data2, data3, data4, num, y_label):
    x = np.linspace(0, 200, num)
    plt.figure(figsize=(10, 5))
    plt.plot(x, data1, 'o-')
    plt.plot(x, data2, 'o-')
    plt.plot(x, data3, 'o-')
    plt.plot(x, data4, 'o-')
    
    plt.title("Different iHMM's performance on HMM-generated observation")
    plt.xlabel('Iterations')
    plt.ylabel(y_label)
    plt.ylim(0, 20)
    
    plt.legend(['iHMM trained with 8 states 500 observation', 'iHMM trained with 16 states 500 observation', 'iHMM trained with 8 states 5000 observation', 'iHMM trained with 16 states 5000 observation'])
    plt.show()

# %%
loss1 = [88.8, 71.9, 35.7, 33.3, 31.1, 32.1, 30.7, 31.3, 31.8, 30.7, 29.3, 24.6, 20.6, 21.1, 21.7, 21.7, 20.6, 21.0, 20.1, 20.0, 20.6]
loss2 = [87.3, 82.8, 68.5, 49.7, 45.9, 46.3, 42.5, 38.7, 37.7, 37.9, 36.7, 36.9, 36.7, 37.3, 35.9, 31.6, 32.0, 32.6, 32.0, 32.8, 32.6]
loss3 = [87.9, 74.2, 55.5, 53.6, 54.3, 54.5, 54.8, 56.0, 54.3, 55.4, 56.1, 55.8, 51.0, 49.8, 49.8, 48.7, 48.1, 47.7, 48.3, 47.7, 47.1]
loss4= [89.2, 74.9, 67.7, 57.4, 54.2, 52.2, 52.1, 51.4, 50.7, 50.2, 50.3, 51.0, 50.2, 51.1, 49.7, 49.8, 49.5, 49.7, 50.7, 50.8, 51.5]
plot(loss1, loss2, loss3, loss4, 21, 'Zero-one loss')
# Out:
# (0, 89.2)
# (10, 74.9)
# (20, 67.7)
# (30, 57.4)
# (40, 54.2)
# (50, 52.2)
# (60, 52.1)
# (70, 51.4)
# (80, 50.7)
# (90, 50.2)
# (100, 50.3)
# (110, 51.0)
# (120, 50.2)
# (130, 51.1)
# (140, 49.7)
# (150, 49.8)
# (160, 49.5)
# (170, 49.7)
# (180, 50.7)
# (190, 50.8)
# (200, 51.5)

# %%
def plot(data1, data2, data3, data4, num, y_label):
    x = np.linspace(0, 50, num)
    plt.figure(figsize=(10, 5))
    plt.plot(x, data1, 'o-')
    plt.plot(x, data2, 'x-')
    plt.plot(x, data3, 'o-')
    plt.plot(x, data4, 'x-')
    
    plt.title("iHMMs' PoS tagging performance on PTB and Childes dataset")
    plt.xlabel('Iterations')
    plt.ylabel(y_label)
    plt.ylim(10, 20)
    
    plt.legend(['PTB dataset with sampled hyperparams', 'PTB dataset with fixed hyperparams', 'Childes dataset with sampled hyperparams', 'Childes dataset with fixed hyperparams'])
    
    plt.show()

# %%
ptb_sampled_loss = [90.414, 74.566, 66.757, 61.856, 56.879, 52.479, 49.069, 46.83, 45.516, 44.622, 44.032, 43.678, 43.441, 43.196, 43.038, 42.824, 42.722, 42.639, 42.577, 42.614, 42.606]
ptb_fixed_loss = [89.2, 81.391, 78.761, 75.669, 70.382, 67.329, 64.47, 61.673, 59.071, 56.98, 53.493, 52.19, 51.128, 50.343, 49.769, 49.364, 49.07, 48.763, 48.556, 48.4, 48.299]
childes_fixed_loss = [92.121, 87.582, 83.335, 72.998, 71.88, 69.931, 67.281, 64.363, 61.313, 58.094, 54.677, 51.396, 48.689, 45.82, 45.038, 44.501, 44.21, 44.163, 44.164, 44.135, 44.174]
childes_sampled_loss = [92.121, 83.178, 72.728, 69.221, 66.277, 63.026, 59.431, 55.409, 51.477, 48.45, 46.608, 45.005, 44.387, 43.797, 43.149, 42.914, 41.763, 41.782, 41.879, 41.988, 41.845]
x_axis = np.linspace(0, 60, 21)
for i in range(21):
    print(tuple((int(x_axis[i]), round(childes_fixed_loss[i], 1))))
# plot(ptb_sampled_loss, ptb_fixed_loss, childes_sampled_loss, childes_fixed_loss, 21, 'Zero-one loss')
# Out:
# (0, 92.1)
# (3, 87.6)
# (6, 83.3)
# (9, 73.0)
# (12, 71.9)
# (15, 69.9)
# (18, 67.3)
# (21, 64.4)
# (24, 61.3)
# (27, 58.1)
# (30, 54.7)
# (33, 51.4)
# (36, 48.7)
# (39, 45.8)
# (42, 45.0)
# (45, 44.5)
# (48, 44.2)
# (51, 44.2)
# (54, 44.2)
# (57, 44.1)
# (60, 44.2)

# %%
ptb_sampled_states = [16, 16, 16, 17, 17, 17, 17, 18, 16, 17, 17, 18, 19, 17, 19, 16, 15, 15, 15, 15]
ptb_fixed_states = [16, 16, 16, 16, 16, 16, 17, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]
childes_fixed_states = [16, 16, 16, 16, 17, 16, 16, 16, 17, 17, 17, 17, 16, 16, 16, 16, 16, 16, 16, 16]
childes_sampled_states = [16, 16, 16, 16, 16, 18, 18, 17, 17, 17, 17, 17, 18, 18, 17, 16, 16, 16, 16, 16]
for i in range(20):
    print(tuple((int(x_axis[i]), round(childes_fixed_states[i], 1))))
# plot(ptb_sampled_states, ptb_fixed_states, childes_sampled_states, childes_fixed_states, 20, 'Number of hidden states')
# Out:
# (0, 16)
# (3, 16)
# (6, 16)
# (9, 16)
# (12, 17)
# (15, 16)
# (18, 16)
# (21, 16)
# (24, 17)
# (27, 17)
# (30, 17)
# (33, 17)
# (36, 16)
# (39, 16)
# (42, 16)
# (45, 16)
# (48, 16)
# (51, 16)
# (54, 16)
# (57, 16)

# %%
def plot(data1, data2, data3, data4, num1, num2, y_label):
    x1 = np.linspace(0, 50, num1)
    x2 = np.linspace(0, 50, num2)
    plt.figure(figsize=(10, 5))
    plt.plot(x1, data1, 'ro-')
    plt.plot(x1, data2, 'go-')
    plt.plot(x2, data3, 'rx-')
    plt.plot(x2, data4, 'gx-')
    
    plt.title("")
    plt.xlabel('Iterations')
    plt.ylabel(y_label)
    plt.ylim(0, 10)
    
    plt.legend(['alpha for Penn Treebank', 'gamma for Penn Treebank', 'alpha for CHILDES', 'gamma for CHILDES'])
    
    plt.show()

# %%
ptb_alpha=  [0.8       , 1.53501765, 2.56334837, 3.43182242, 4.1825933 ,
       4.76573091, 5.21384409, 6.00283318, 6.37186186, 6.94406582,
       7.42579112, 7.53528547, 8.02965426, 8.56987143, 8.90275238,
       9.30665334, 9.16216426, 8.9187885 , 8.69756971, 7.94189885,
       7.04955864, 5.93803284, 5.43527443, 5.66514995, 4.89620323,
       4.36817766, 3.70883139, 3.50509608, 3.34687783, 2.93069617,
       2.77061412]
ptb_gamma= [5.        , 2.37909536, 2.85414202, 1.78853161, 1.37653838,
       2.46438209, 2.00638882, 1.92855646, 2.24437846, 3.044678  ,
       2.37032841, 2.22803886, 2.79943812, 3.53917421, 2.94020543,
       2.44985285, 1.25308984, 2.8650661 , 1.68734229, 2.19245323,
       1.69230744, 1.97002699, 2.96058688, 1.05329991, 1.62188377,
       2.27323907, 3.21317311, 3.02595289, 3.00703537, 2.12505488,
       1.85778595]
childes_alpha = [0.8       , 1.14383264, 1.73269884, 2.50407561, 3.21209624,
       3.45923337, 3.90312486, 5.06725225, 5.82653826, 5.72048981,
       5.38834766, 5.59554202, 5.20880017, 4.83901332, 4.75148176,
       4.00964739, 4.289705  , 4.36632005, 4.05486802, 3.65973135,
       2.97663028]
childes_gamma= [5.        , 2.05251172, 2.34634302, 1.67647807, 2.32206266,
       1.64226994, 2.69126567, 1.98191663, 1.90397073, 1.86279195,
       1.55812909, 1.58279853, 3.12474826, 2.1480187 , 0.99568844,
       2.09075169, 2.28414977, 1.29777657, 1.88275759, 3.14558458,
       1.64722269]
# Out:
# (0, 5.0)
# (3, 2.1)
# (6, 2.3)
# (9, 1.7)
# (12, 2.3)
# (15, 1.6)
# (18, 2.7)
# (21, 2.0)
# (24, 1.9)
# (27, 1.9)
# (30, 1.6)
# (33, 1.6)
# (36, 3.1)
# (39, 2.1)
# (42, 1.0)
# (45, 2.1)
# (48, 2.3)
# (51, 1.3)
# (54, 1.9)
# (57, 3.1)
# (60, 1.6)

# %%
plot(ptb_alpha, ptb_gamma, childes_alpha, childes_gamma, 31, 21, 'Value of alpha & gamma')

# %%
def plot(data1, data2, num1, y_label):
    x1 = np.linspace(0, 50, num1)
    plt.figure(figsize=(10, 5))
    plt.plot(x1, data1, 'o-')
    plt.plot(x1, data2, 'o-')
    
    # plt.title("")
    plt.xlabel('Iterations')
    plt.ylabel(y_label)
    plt.ylim(0, 10)
    
    plt.legend(['PTB dataset with sampled hyperparams', 'PTB dataset with fixed hyperparams'])
    
    plt.show()

# %%
ptb_vi_sampled = [6.397, 6.207, 5.270, 4.374, 4.035, 3.917, 3.864, 3.839, 3.825, 3.813, 3.812]
ptb_vi_fixed = [6.597, 6.576, 6.440, 6.102, 5.451, 4.804, 4.388, 4.176, 4.087, 4.038, 4.014]
ptb_homo = [0.117, 0.142, 0.264, 0.379, 0.421, 0.435, 0.443, 0.447, 0.449, 0.451, 0.452]
ptb_comp = [0.105, 0.128, 0.246, 0.364, 0.410, 0.427, 0.435, 0.438, 0.440, 0.442, 0.442]
ptb_vmeasure = [0.111, 0.135, 0.255, 0.372, 0.416, 0.431, 0.439, 0.442, 0.445, 0.446, 0.447]
x_axis = np.linspace(0, 60, 11)
for i in range(11):
    print(tuple((int(x_axis[i]), round(ptb_vmeasure[i], 3))))
# Out:
# (0, 0.111)
# (6, 0.135)
# (12, 0.255)
# (18, 0.372)
# (24, 0.416)
# (30, 0.431)
# (36, 0.439)
# (42, 0.442)
# (48, 0.445)
# (54, 0.446)
# (60, 0.447)

# %%
def plot(data1, data2, data3, num1, y_label):
    x1 = np.linspace(0, 50, num1)
    plt.figure(figsize=(10, 5))
    plt.plot(x1, data1, ':')
    plt.plot(x1, data2, ':')
    plt.plot(x1, data3, 'k-')
    
    # plt.title("")
    plt.xlabel('Iterations')
    plt.ylabel(y_label)
    plt.ylim(0, 0.5)
    
    plt.legend(['Homogeneity', 'Completeness', 'V-Measure'])
    
    plt.show()

# %%
plot(ptb_homo, ptb_comp, ptb_vmeasure, 11, 'V-Measure score')

# %%
plot(ptb_homo, ptb_comp, ptb_vmeasure, 11, 'V-Measure score')
